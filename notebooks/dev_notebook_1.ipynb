# %% [markdown]
# ### dev_notebook_
#
# - Your development environment...

# %%
#import libraries...
import pandas as pd 
import numpy as np
import requests

# %%
base_url = 'https://datos.madrid.es/egob'
mujib = '/catalogo/209434-0-templos-otros.json'

# %%
full_endpoint = (base_url + mujib)
full_endpoint
# Out:
# 'https://datos.madrid.es/egob/catalogo/209434-0-templos-otros.json'

# %%
response = requests.get(full_endpoint).json()
response
# Out:
# {'@context': {'c': 'http://www.w3.org/2002/12/cal#',
#   'dcterms': 'http://purl.org/dc/terms/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'loc': 'http://purl.org/ctic/infraestructuras/localizacion#',
#   'org': 'http://purl.org/ctic/infraestructuras/organizacion#',
#   'vcard': 'http://www.w3.org/2006/vcard/ns#',
#   'schema': 'https://schema.org/',
#   'title': 'vcard:fn',
#   'id': 'dcterms:identifier',
#   'relation': 'dcterms:relation',
#   'references': 'dcterms:references',
#   'address': 'vcard:adr',
#   'area': 'loc:barrio',
#   'district': 'loc:distrito',
#   'locality': 'vcard:locality',
#   'postal-code': 'vcard:postal-code',
#   'street-address': 'vcard:street-address',
#   'location': 'vcard:geo',
#   'latitude': 'geo:lat',
#   'longitude': 'geo:long',
#   'organization': 'vcard:org',
#   'organization-desc': 'dcterms:description',
#   'accesibility': 'org:accesibilidad',
#   'services': 'org:servicios',
#   'schedule': 'org:horario',
# ...

# %%
type(response)
# Out:
# dict

# %%
response.keys()
# Out:
# dict_keys(['@context', '@graph'])

# %%
response['@context']
# Out:
# {'c': 'http://www.w3.org/2002/12/cal#',
#  'dcterms': 'http://purl.org/dc/terms/',
#  'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#  'loc': 'http://purl.org/ctic/infraestructuras/localizacion#',
#  'org': 'http://purl.org/ctic/infraestructuras/organizacion#',
#  'vcard': 'http://www.w3.org/2006/vcard/ns#',
#  'schema': 'https://schema.org/',
#  'title': 'vcard:fn',
#  'id': 'dcterms:identifier',
#  'relation': 'dcterms:relation',
#  'references': 'dcterms:references',
#  'address': 'vcard:adr',
#  'area': 'loc:barrio',
#  'district': 'loc:distrito',
#  'locality': 'vcard:locality',
#  'postal-code': 'vcard:postal-code',
#  'street-address': 'vcard:street-address',
#  'location': 'vcard:geo',
#  'latitude': 'geo:lat',
#  'longitude': 'geo:long',
#  'organization': 'vcard:org',
#  'organization-desc': 'dcterms:description',
#  'accesibility': 'org:accesibilidad',
#  'services': 'org:servicios',
#  'schedule': 'org:horario',
#  'organization-name': 'vcard:organization-name',
# ...

# %%
type(response['@context'])
# Out:
# dict

# %%
#df = pd.DataFrame(response['@context'],[0])
#all_columns_rows = df.loc[:, :]

# %%
df = pd.DataFrame(response['@context'],[0])
df
# Out:
#                                 c                    dcterms  \
# 0  http://www.w3.org/2002/12/cal#  http://purl.org/dc/terms/
#
#                                         geo  \
# 0  http://www.w3.org/2003/01/geo/wgs84_pos#
#
#                                                  loc  \
# 0  http://purl.org/ctic/infraestructuras/localiza...
#
#                                                  org  \
# 0  http://purl.org/ctic/infraestructuras/organiza...
#
#                               vcard               schema     title  \
# 0  http://www.w3.org/2006/vcard/ns#  https://schema.org/  vcard:fn
#
#                    id          relation  ...    time excluded-days  \
# 0  dcterms:identifier  dcterms:relation  ...  c:time      c:exdate
#
#   event-location         free       price recurrence     days frequency  \
# 0     c:location  schema:free  c:resource    c:rrule  c:byday    c:freq
#
#      interval     audience
# 0  c:interval  dc:audience
#
# [1 rows x 41 columns]

# %%
response['@graph']
# Out:
# [{'@id': 'https://datos.madrid.es/egob/catalogo/tipo/entidadesyorganismos/11772877-asamblea-cristiana-gilgal.json',
#   '@type': 'https://datos.madrid.es/egob/kos/entidadesYorganismos/TemplosOtrasReligiones',
#   'id': '11772877',
#   'title': 'Asamblea Cristiana Gilgal',
#   'relation': 'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=bfa48ab43d6bb410VgnVCM100000171f5a0aRCRD&vgnextoid=1f2d6e4d59043810VgnVCM1000001d4a900aRCRD',
#   'address': {'district': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas'},
#    'area': {'@id': 'https://datos.madrid.es/egob/kos/Provincia/Madrid/Municipio/Madrid/Distrito/PuenteDeVallecas/Barrio/Numancia'},
#    'locality': 'MADRID',
#    'postal-code': '28038',
#    'street-address': 'CALLE GARGANTA DE AISA 34'},
#   'location': {'latitude': 40.403023480440126,
#    'longitude': -3.6575752658298923},
#   'organization': {'organization-desc': 'Templo evangélico.\xa0\xa0Bus:  141, 133, 8.',
# ...

# %%
type(response['@graph'])
# Out:
# list

# %%
type(response['@graph'][0])
# Out:
# dict

# %%
df1 = pd.json_normalize(response['@graph'])
df1
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 5    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 6    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 7    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 8    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 9    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 10   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 11   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 12   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 13   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 14   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 15   https://datos.madrid.es/egob/catalogo/tipo/ent...
# ...

# %%
temples = df1[['title','address.street-address','location.latitude','location.longitude','organization.organization-name']]
temples
# Out:
#                                                  title  \
# 0                            Asamblea Cristiana Gilgal
# 1    Asambleas de Evangelización Mundial para Crist...
# 2    Asociación Darse - Dar Ayuda para la Reinserci...
# 3                  Asociación Evangélica Internacional
# 4                         Catedral Anglicana de Madrid
# 5    Catedral Ortodoxa Griega. Santa Iglesia Catedr...
# 6                       Centro Apostólico Cristo Viene
# 7                           Centro Cristiano Amor y Fe
# 8                   Centro Cristiano Ciudad de Refugio
# 9                      Centro Cristiano Cuatro Caminos
# 10                         Centro Cristiano Evangélico
# 11           Centro Cristiano Evangélico Independiente
# 12        Centro Cultural Islámico. Mezquita de Madrid
# 13             Centro de Evangelización Anuncio de Paz
# 14              Centro de Fe y Esperanza Internacional
# 15   Centro Evangélico de Restauración Aliento de Vida
# ...

# %%
temples.columns = ['Place of interest', 'Place address', 'Latitude', 'Longitude', 'Type of place']
temples
# Out:
#                                      Place of interest  \
# 0                            Asamblea Cristiana Gilgal
# 1    Asambleas de Evangelización Mundial para Crist...
# 2    Asociación Darse - Dar Ayuda para la Reinserci...
# 3                  Asociación Evangélica Internacional
# 4                         Catedral Anglicana de Madrid
# 5    Catedral Ortodoxa Griega. Santa Iglesia Catedr...
# 6                       Centro Apostólico Cristo Viene
# 7                           Centro Cristiano Amor y Fe
# 8                   Centro Cristiano Ciudad de Refugio
# 9                      Centro Cristiano Cuatro Caminos
# 10                         Centro Cristiano Evangélico
# 11           Centro Cristiano Evangélico Independiente
# 12        Centro Cultural Islámico. Mezquita de Madrid
# 13             Centro de Evangelización Anuncio de Paz
# 14              Centro de Fe y Esperanza Internacional
# 15   Centro Evangélico de Restauración Aliento de Vida
# ...

# %%
temples.to_csv('../data/temples_api.csv', index=False)
